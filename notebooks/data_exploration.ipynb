# %%
import os
# spark session
from pyspark.sql import SparkSession

# config - when tuining spark jobs, (memory, shufflepartitions,..)
spark = SparkSession.builder.appName(" Python Spark SQL demo").getOrCreate()
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/09/08 15:46:51 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
# read files 
device_list_df = spark.read.csv("../data/raw_data/devices_list.csv",header=True,inferSchema=True)

# %%
# print first n rows of dataframe
device_list_df.show()
# Out:
# +-----------+------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+------------------+------------------+------------------+------------------+
# |Device name|Active|           Road (nl)|           Road (fr)|           Road (en)|    Description (nl)|    Description (fr)|    Description (en)|         Lane schema|        Basic schema|     Detailed schema|           Picture 1|           Picture 2|      Lon (WGS 84)|      Lat (WGS 84)|          X (Lb72)|          Y (Lb72)|
# +-----------+------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+------------------+------------------+------------------+------------------+
# |      CAT17|  true|Veeweidekaai 11 -...|Quai de Veeweyde ...|Quai de Veeweyde ...|Veeweidekaai 11 -...|Quai de Veeweyde ...|Quai de Veeweyde ...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...| 4.301991995919691|50.820621002525904|145295.77384021957|167800.59543291386|
# |    CB02411|  true|Vilvoordsesteenwe...|ChaussÃ©e de Vilv...|ChaussÃ©e de Vilv...|Vilvoordsesteenwe...|ChaussÃ©e de Vilv...|ChaussÃ©e de Vilv...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...| 4.373960995908418| 50.88185000251615|150366.52086226034| 174609.7089257436|
# |     CB1101|  true|Kunstlaan 26 - 10...|Avenue des Arts 2...|Avenue des Arts 2...|Kunstlaan 26 - 10...|Avenue des Arts 2...|Avenue des Arts 2...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|  4.36858299590588| 50.84534100252618|149988.08238897286|170548.38497496303|
# |     CB1142|  true|Wetstraat 130 - 1...|Rue de la Loi 130...|Rue de la Loi 130...|De aantallen zijn...|Les nombres sont ...|Wetstraat 130 - 1...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...| 4.378737995903186|50.843570002527876|150703.30572719825|170351.43165755924|
# |     CB1143|  true|Wetstraat 145 - 1...|Rue de la Loi 145...|Rue de la Loi 145...|Wetstraat 145 - 1...|Rue de la Loi 145...|Rue de la Loi 145...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...| 4.378813995903146| 50.84337000252792|  150708.661668213|170329.18430125527|
# |     CB1599|  true|Franklin Roosevel...|Avenue Franklin R...|Avenue Franklin R...|Franklin Roosevel...|Avenue Franklin R...|Avenue Franklin R...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...| 4.379253995899753| 50.81240800253699|150740.17032080193|166884.97076604702|
# |     CB1699|  true|Franklin Roosevel...|Avenue Franklin R...|Avenue Franklin R...|Franklin Roosevel...|Avenue Franklin R...|Avenue Franklin R...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...| 4.378799995899851| 50.81228000253699|150708.17572737113|166870.72735976242|
# |     CB2105|  true|PoincarÃ©laan 75 ...|Boulevard Poincar...|Boulevard Poincar...|PoincarÃ©laan 75 ...|Boulevard Poincar...|Boulevard Poincar...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...| 4.340009995912418| 50.84048000252439| 147975.5426188648|170008.01742326748|
# |     CEE016|  true|Generaal Jacquesl...|Avenue GÃ©nÃ©ral ...|Avenue GÃ©nÃ©ral ...|Generaal Jacquesl...|Avenue GÃ©nÃ©ral ...|Avenue GÃ©nÃ©ral ...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...| 4.386718995898861| 50.82137600253522|151266.03202625556|167882.67534628976|
# |     CEK049|  true|Generaal Jacquesl...|Boulevard GÃ©nÃ©r...|Boulevard GÃ©nÃ©r...|Generaal Jacquesl...|Boulevard GÃ©nÃ©r...|Boulevard GÃ©nÃ©r...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...| 4.393892995897416| 50.82448000253513|151771.41899748406|168228.11577489227|
# |      CEK18|  true|Tervurenlaan 28 -...|Avenue de Tervuer...|Avenue de Tervuer...|Tervurenlaan 28 -...|Avenue de Tervuer...|Avenue de Tervuer...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...| 4.400258995897405| 50.83920000253155|  152219.251732101|169865.74793962855|
# |      CEK31|  true|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...| 4.393037995899081| 50.83818200253104|151710.66377625745|169752.30930852424|
# |     CEV011|  true|Leopold III laan ...|Avenue LÃ©opold I...|Avenue LÃ©opold I...|Leopold III laan ...|Avenue LÃ©opold I...|Avenue LÃ©opold I...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...| 4.402934995899683| 50.86692100252375|152406.29305723993|172949.54288042616|
# |     CJE181|  true|Tentoonstellingsl...|Avenue de l'Expos...|Avenue de l'Expos...|Tentoonstellingsl...|Avenue de l'Expos...|Avenue de l'Expos...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...| 4.315713995922622| 50.88029700251005| 146267.3731625433|174438.23254681192|
# |      CJM90|  true|Koolmijnenkaai 8 ...|Quai des Charbonn...|Quai des Charbonn...|Koolmijnenkaai 8 ...|Quai des Charbonn...|Quai des Charbonn...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...| 4.341239995913506|  50.8536300025207|148062.70628520215|171470.80123403482|
# |     CLW239|  true|Woluwelaan 34 - 1...|Boulevard de la W...|Boulevard de la W...|Woluwelaan 34 - 1...|Boulevard de la W...|Boulevard de la W...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|4.4348299958887285| 50.83799800253579| 154654.4513592448|169733.65965939965|
# |     COM205|  true|Vorstlaan 213 - 1...|Boulevard du Souv...|Boulevard du Souv...|Vorstlaan 213 - 1...|Boulevard du Souv...|Boulevard du Souv...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...| 4.430120995888016| 50.82029000254048|154324.40118714384|167763.53100199532|
# |     CVT387|  true|Hallestraat 164 -...|rue de Hal 164 - ...|rue de Hal 164 - ...|Hallestraat 164 -...|rue de Hal 164 - ...|rue de Hal 164 - ...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...| 4.311588995915708|50.805366002531436|145970.73461078262|166103.07591880858|
# +-----------+------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+------------------+------------------+------------------+------------------+

# %%
# read the bike counts
bike_count_df = spark.read.csv("../data/raw_data/raw_data.csv",header=True, inferSchema=True)

# %%
bike_count_df.show(10)
# Out:
# +----------+--------+-----+-------------+-----------+
# |      Date|Time gap|Count|Average speed|device_name|
# +----------+--------+-----+-------------+-----------+
# |2020-11-23|      93|    0|           -1|      CEK31|
# |2020-11-23|      94|    0|           -1|      CEK31|
# |2020-11-23|      95|    0|           -1|      CEK31|
# |2020-11-23|      96|    0|           -1|      CEK31|
# |2020-11-24|       1|    0|           -1|      CEK31|
# |2020-11-24|       2|    0|           -1|      CEK31|
# |2020-11-24|       3|    0|           -1|      CEK31|
# |2020-11-24|       4|    0|           -1|      CEK31|
# |2020-11-24|       5|    0|           -1|      CEK31|
# |2020-11-24|       6|    0|           -1|      CEK31|
# +----------+--------+-----+-------------+-----------+
# only showing top 10 rows

# %%
bike_count_df.head(5)
# Out:
# [Row(Date=datetime.date(2020, 11, 23), Time gap=93, Count=0, Average speed=-1, device_name='CEK31'),
#  Row(Date=datetime.date(2020, 11, 23), Time gap=94, Count=0, Average speed=-1, device_name='CEK31'),
#  Row(Date=datetime.date(2020, 11, 23), Time gap=95, Count=0, Average speed=-1, device_name='CEK31'),
#  Row(Date=datetime.date(2020, 11, 23), Time gap=96, Count=0, Average speed=-1, device_name='CEK31'),
#  Row(Date=datetime.date(2020, 11, 24), Time gap=1, Count=0, Average speed=-1, device_name='CEK31')]

# %%
# tasks for pyspark
# join the device_list and the bike_count tables
# clean (missing count, standardize station names), enrich ith weathre data, parse and cast types, transform and 
# aggregate raw bike counts using DataFrames/SQL : total rides, busiest stations, hourly/daily/weekly trends, peak usage windows
# 
## Business Value
# Scalable insights: millions of bike count records across years, stations
# Real-time analytics: spot sudden spikes/operational outagaes instantly
# Data quality: automate correction and completeness checks
# Advanced Reporting: maooing, visualisation and predictive analytics for urban, operations, marketing teams

# %%
# rename columns
# bike count data
bike_count_df = bike_count_df.toDF(*(c.lower().replace(" ","_") for c in bike_count_df.columns))

bike_count_df.show(10)
# Out:
# +----------+--------+-----+-------------+-----------+
# |      date|time_gap|count|average_speed|device_name|
# +----------+--------+-----+-------------+-----------+
# |2020-11-23|      93|    0|           -1|      CEK31|
# |2020-11-23|      94|    0|           -1|      CEK31|
# |2020-11-23|      95|    0|           -1|      CEK31|
# |2020-11-23|      96|    0|           -1|      CEK31|
# |2020-11-24|       1|    0|           -1|      CEK31|
# |2020-11-24|       2|    0|           -1|      CEK31|
# |2020-11-24|       3|    0|           -1|      CEK31|
# |2020-11-24|       4|    0|           -1|      CEK31|
# |2020-11-24|       5|    0|           -1|      CEK31|
# |2020-11-24|       6|    0|           -1|      CEK31|
# +----------+--------+-----+-------------+-----------+
# only showing top 10 rows

# %%
# device list 
import re
def clean_col_name(col):
    # lowercase
    col = col.lower()

    # replace the space and dot with underscore
    col = re.sub(r"[ .]+","_",col)

    #remove parantheses,commas, or any other special characters
    col = re.sub(r"[(),]","",col)

    # remove extra underscores from multiple replacements

    col = re.sub(r"__+","_",col)

    return col


device_list_df = device_list_df.toDF(*(clean_col_name(c) for c in device_list_df.columns))

# %%
# visualise the device_list_df

device_list_df.show()
# Out:
# +-----------+------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+------------------+------------------+------------------+------------------+
# |device_name|active|             road_nl|             road_fr|             road_en|      description_nl|      description_fr|      description_en|         lane_schema|        basic_schema|     detailed_schema|           picture_1|           picture_2|        lon_wgs_84|        lat_wgs_84|            x_lb72|            y_lb72|
# +-----------+------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+------------------+------------------+------------------+------------------+
# |      CAT17|  true|Veeweidekaai 11 -...|Quai de Veeweyde ...|Quai de Veeweyde ...|Veeweidekaai 11 -...|Quai de Veeweyde ...|Quai de Veeweyde ...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...| 4.301991995919691|50.820621002525904|145295.77384021957|167800.59543291386|
# |    CB02411|  true|Vilvoordsesteenwe...|ChaussÃ©e de Vilv...|ChaussÃ©e de Vilv...|Vilvoordsesteenwe...|ChaussÃ©e de Vilv...|ChaussÃ©e de Vilv...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...| 4.373960995908418| 50.88185000251615|150366.52086226034| 174609.7089257436|
# |     CB1101|  true|Kunstlaan 26 - 10...|Avenue des Arts 2...|Avenue des Arts 2...|Kunstlaan 26 - 10...|Avenue des Arts 2...|Avenue des Arts 2...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|  4.36858299590588| 50.84534100252618|149988.08238897286|170548.38497496303|
# |     CB1142|  true|Wetstraat 130 - 1...|Rue de la Loi 130...|Rue de la Loi 130...|De aantallen zijn...|Les nombres sont ...|Wetstraat 130 - 1...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...| 4.378737995903186|50.843570002527876|150703.30572719825|170351.43165755924|
# |     CB1143|  true|Wetstraat 145 - 1...|Rue de la Loi 145...|Rue de la Loi 145...|Wetstraat 145 - 1...|Rue de la Loi 145...|Rue de la Loi 145...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...| 4.378813995903146| 50.84337000252792|  150708.661668213|170329.18430125527|
# |     CB1599|  true|Franklin Roosevel...|Avenue Franklin R...|Avenue Franklin R...|Franklin Roosevel...|Avenue Franklin R...|Avenue Franklin R...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...| 4.379253995899753| 50.81240800253699|150740.17032080193|166884.97076604702|
# |     CB1699|  true|Franklin Roosevel...|Avenue Franklin R...|Avenue Franklin R...|Franklin Roosevel...|Avenue Franklin R...|Avenue Franklin R...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...| 4.378799995899851| 50.81228000253699|150708.17572737113|166870.72735976242|
# |     CB2105|  true|PoincarÃ©laan 75 ...|Boulevard Poincar...|Boulevard Poincar...|PoincarÃ©laan 75 ...|Boulevard Poincar...|Boulevard Poincar...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...| 4.340009995912418| 50.84048000252439| 147975.5426188648|170008.01742326748|
# |     CEE016|  true|Generaal Jacquesl...|Avenue GÃ©nÃ©ral ...|Avenue GÃ©nÃ©ral ...|Generaal Jacquesl...|Avenue GÃ©nÃ©ral ...|Avenue GÃ©nÃ©ral ...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...| 4.386718995898861| 50.82137600253522|151266.03202625556|167882.67534628976|
# |     CEK049|  true|Generaal Jacquesl...|Boulevard GÃ©nÃ©r...|Boulevard GÃ©nÃ©r...|Generaal Jacquesl...|Boulevard GÃ©nÃ©r...|Boulevard GÃ©nÃ©r...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...| 4.393892995897416| 50.82448000253513|151771.41899748406|168228.11577489227|
# |      CEK18|  true|Tervurenlaan 28 -...|Avenue de Tervuer...|Avenue de Tervuer...|Tervurenlaan 28 -...|Avenue de Tervuer...|Avenue de Tervuer...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...| 4.400258995897405| 50.83920000253155|  152219.251732101|169865.74793962855|
# |      CEK31|  true|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...| 4.393037995899081| 50.83818200253104|151710.66377625745|169752.30930852424|
# |     CEV011|  true|Leopold III laan ...|Avenue LÃ©opold I...|Avenue LÃ©opold I...|Leopold III laan ...|Avenue LÃ©opold I...|Avenue LÃ©opold I...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...| 4.402934995899683| 50.86692100252375|152406.29305723993|172949.54288042616|
# |     CJE181|  true|Tentoonstellingsl...|Avenue de l'Expos...|Avenue de l'Expos...|Tentoonstellingsl...|Avenue de l'Expos...|Avenue de l'Expos...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...| 4.315713995922622| 50.88029700251005| 146267.3731625433|174438.23254681192|
# |      CJM90|  true|Koolmijnenkaai 8 ...|Quai des Charbonn...|Quai des Charbonn...|Koolmijnenkaai 8 ...|Quai des Charbonn...|Quai des Charbonn...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...| 4.341239995913506|  50.8536300025207|148062.70628520215|171470.80123403482|
# |     CLW239|  true|Woluwelaan 34 - 1...|Boulevard de la W...|Boulevard de la W...|Woluwelaan 34 - 1...|Boulevard de la W...|Boulevard de la W...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|4.4348299958887285| 50.83799800253579| 154654.4513592448|169733.65965939965|
# |     COM205|  true|Vorstlaan 213 - 1...|Boulevard du Souv...|Boulevard du Souv...|Vorstlaan 213 - 1...|Boulevard du Souv...|Boulevard du Souv...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...| 4.430120995888016| 50.82029000254048|154324.40118714384|167763.53100199532|
# |     CVT387|  true|Hallestraat 164 -...|rue de Hal 164 - ...|rue de Hal 164 - ...|Hallestraat 164 -...|rue de Hal 164 - ...|rue de Hal 164 - ...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...| 4.311588995915708|50.805366002531436|145970.73461078262|166103.07591880858|
# +-----------+------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+------------------+------------------+------------------+------------------+

# %%
device_list_df.schema
# Out:
# StructType([StructField('device_name', StringType(), True), StructField('active', BooleanType(), True), StructField('road_nl', StringType(), True), StructField('road_fr', StringType(), True), StructField('road_en', StringType(), True), StructField('description_nl', StringType(), True), StructField('description_fr', StringType(), True), StructField('description_en', StringType(), True), StructField('lane_schema', StringType(), True), StructField('basic_schema', StringType(), True), StructField('detailed_schema', StringType(), True), StructField('picture_1', StringType(), True), StructField('picture_2', StringType(), True), StructField('lon_wgs_84', DoubleType(), True), StructField('lat_wgs_84', DoubleType(), True), StructField('x_lb72', DoubleType(), True), StructField('y_lb72', DoubleType(), True)])

# %%
# perform a join on bike_count
bike_count_df.count()
# > 3 million records
# Out:
# 3059094

# %%
# perform a join on bike_count
bike_join = bike_count_df.join(device_list_df,on='device_name',how='left')

# %%
bike_join.schema
# Out:
# StructType([StructField('device_name', StringType(), True), StructField('date', DateType(), True), StructField('time_gap', IntegerType(), True), StructField('count', IntegerType(), True), StructField('average_speed', IntegerType(), True), StructField('active', BooleanType(), True), StructField('road_nl', StringType(), True), StructField('road_fr', StringType(), True), StructField('road_en', StringType(), True), StructField('description_nl', StringType(), True), StructField('description_fr', StringType(), True), StructField('description_en', StringType(), True), StructField('lane_schema', StringType(), True), StructField('basic_schema', StringType(), True), StructField('detailed_schema', StringType(), True), StructField('picture_1', StringType(), True), StructField('picture_2', StringType(), True), StructField('lon_wgs_84', DoubleType(), True), StructField('lat_wgs_84', DoubleType(), True), StructField('x_lb72', DoubleType(), True), StructField('y_lb72', DoubleType(), True)])
# 25/09/08 17:40:00 WARN HeartbeatReceiver: Removing executor driver with no recent heartbeats: 1956153 ms exceeds timeout 120000 ms
# 25/09/08 17:40:00 WARN SparkContext: Killing executors is not supported by current scheduler.
# 25/09/08 17:40:02 WARN Executor: Issue communicating with driver in heartbeater
# org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.SparkThreadUtils$.awaitResult(SparkThreadUtils.scala:53)
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:342)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEndpointRef.askSync(RpcEndpointRef.scala:101)
# 	at org.apache.spark.rpc.RpcEndpointRef.askSync(RpcEndpointRef.scala:85)
# 	at org.apache.spark.storage.BlockManagerMaster.registerBlockManager(BlockManagerMaster.scala:81)
# 	at org.apache.spark.storage.BlockManager.reregister(BlockManager.scala:669)
# 	at org.apache.spark.executor.Executor.reportHeartBeat(Executor.scala:1296)
# 	at org.apache.spark.executor.Executor.$anonfun$heartbeater$1(Executor.scala:307)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.scala:18)
# 	at org.apache.spark.util.Utils$.logUncaughtExceptions(Utils.scala:1937)
# 	at org.apache.spark.Heartbeater$$anon$1.run(Heartbeater.scala:46)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Unknown Source)
# 	at java.base/java.util.concurrent.FutureTask.runAndReset(Unknown Source)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(Unknown Source)
# 	at java.base/java.lang.Thread.run(Unknown Source)
# Caused by: org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.SparkThreadUtils$.awaitResult(SparkThreadUtils.scala:53)
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:342)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRefByURI(RpcEnv.scala:102)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRef(RpcEnv.scala:110)
# 	at org.apache.spark.util.RpcUtils$.makeDriverRef(RpcUtils.scala:36)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.driverEndpoint$lzycompute(BlockManagerMasterEndpoint.scala:132)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$driverEndpoint(BlockManagerMasterEndpoint.scala:131)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$lzycompute$1(BlockManagerMasterEndpoint.scala:700)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$1(BlockManagerMasterEndpoint.scala:699)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$register(BlockManagerMasterEndpoint.scala:739)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint$$anonfun$receiveAndReply$1.applyOrElse(BlockManagerMasterEndpoint.scala:141)
# 	at org.apache.spark.rpc.netty.Inbox.$anonfun$process$1(Inbox.scala:104)
# 	at org.apache.spark.rpc.netty.Inbox.safelyCall(Inbox.scala:216)
# 	at org.apache.spark.rpc.netty.Inbox.process(Inbox.scala:101)
# 	at org.apache.spark.rpc.netty.MessageLoop.org$apache$spark$rpc$netty$MessageLoop$$receiveLoop(MessageLoop.scala:76)
# 	at org.apache.spark.rpc.netty.MessageLoop$$anon$1.run(MessageLoop.scala:42)
# 	... 3 more
# Caused by: org.apache.spark.rpc.RpcEndpointNotFoundException: Cannot find endpoint: spark://CoarseGrainedScheduler@192.168.0.45:53646
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1(NettyRpcEnv.scala:151)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1$adapted(NettyRpcEnv.scala:147)
# 	at scala.concurrent.impl.Promise$Transformation.run(Promise.scala:470)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl.execute(ExecutionContextImpl.scala:21)
# 	at scala.concurrent.impl.Promise$Transformation.submitWithValue(Promise.scala:429)
# 	at scala.concurrent.impl.Promise$DefaultPromise.submitWithValue(Promise.scala:338)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete0(Promise.scala:285)
# 	at scala.concurrent.impl.Promise$Transformation.run(Promise.scala:504)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl.execute(ExecutionContextImpl.scala:21)
# 	at scala.concurrent.impl.Promise$Transformation.submitWithValue(Promise.scala:429)
# 	at scala.concurrent.impl.Promise$DefaultPromise.submitWithValue(Promise.scala:338)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete0(Promise.scala:285)
# 	at scala.concurrent.impl.Promise$Transformation.run(Promise.scala:504)
# 	at scala.concurrent.ExecutionContext$parasitic$.execute(ExecutionContext.scala:222)
# 	at scala.concurrent.impl.Promise$Transformation.submitWithValue(Promise.scala:429)
# 	at scala.concurrent.impl.Promise$DefaultPromise.submitWithValue(Promise.scala:335)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete0(Promise.scala:285)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:278)
# 	at scala.concurrent.Promise.trySuccess(Promise.scala:99)
# 	at scala.concurrent.Promise.trySuccess$(Promise.scala:99)
# 	at scala.concurrent.impl.Promise$DefaultPromise.trySuccess(Promise.scala:104)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.onSuccess$1(NettyRpcEnv.scala:228)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$askAbortable$5(NettyRpcEnv.scala:242)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$askAbortable$5$adapted(NettyRpcEnv.scala:241)
# 	at scala.concurrent.impl.Promise$Transformation.run(Promise.scala:484)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl.execute(ExecutionContextImpl.scala:21)
# 	at scala.concurrent.impl.Promise$Transformation.submitWithValue(Promise.scala:429)
# 	at scala.concurrent.impl.Promise$DefaultPromise.submitWithValue(Promise.scala:338)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete0(Promise.scala:285)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:278)
# 	at scala.concurrent.Promise.complete(Promise.scala:57)
# 	at scala.concurrent.Promise.complete$(Promise.scala:56)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:104)
# 	at scala.concurrent.Promise.success(Promise.scala:91)
# 	at scala.concurrent.Promise.success$(Promise.scala:91)
# 	at scala.concurrent.impl.Promise$DefaultPromise.success(Promise.scala:104)
# 	at org.apache.spark.rpc.netty.LocalNettyRpcCallContext.send(NettyRpcCallContext.scala:50)
# 	at org.apache.spark.rpc.netty.NettyRpcCallContext.reply(NettyRpcCallContext.scala:32)
# 	at org.apache.spark.rpc.netty.RpcEndpointVerifier$$anonfun$receiveAndReply$1.applyOrElse(RpcEndpointVerifier.scala:31)
# 	... 8 more
# 25/09/08 17:40:02 ERROR Inbox: Ignoring error
# org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.SparkThreadUtils$.awaitResult(SparkThreadUtils.scala:53)
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:342)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRefByURI(RpcEnv.scala:102)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRef(RpcEnv.scala:110)
# 	at org.apache.spark.util.RpcUtils$.makeDriverRef(RpcUtils.scala:36)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.driverEndpoint$lzycompute(BlockManagerMasterEndpoint.scala:132)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$driverEndpoint(BlockManagerMasterEndpoint.scala:131)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$lzycompute$1(BlockManagerMasterEndpoint.scala:700)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$1(BlockManagerMasterEndpoint.scala:699)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$register(BlockManagerMasterEndpoint.scala:739)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint$$anonfun$receiveAndReply$1.applyOrElse(BlockManagerMasterEndpoint.scala:141)
# 	at org.apache.spark.rpc.netty.Inbox.$anonfun$process$1(Inbox.scala:104)
# 	at org.apache.spark.rpc.netty.Inbox.safelyCall(Inbox.scala:216)
# 	at org.apache.spark.rpc.netty.Inbox.process(Inbox.scala:101)
# 	at org.apache.spark.rpc.netty.MessageLoop.org$apache$spark$rpc$netty$MessageLoop$$receiveLoop(MessageLoop.scala:76)
# 	at org.apache.spark.rpc.netty.MessageLoop$$anon$1.run(MessageLoop.scala:42)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(Unknown Source)
# 	at java.base/java.lang.Thread.run(Unknown Source)
# Caused by: org.apache.spark.rpc.RpcEndpointNotFoundException: Cannot find endpoint: spark://CoarseGrainedScheduler@192.168.0.45:53646
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1(NettyRpcEnv.scala:151)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1$adapted(NettyRpcEnv.scala:147)
# 	at scala.concurrent.impl.Promise$Transformation.run(Promise.scala:470)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl.execute(ExecutionContextImpl.scala:21)
# 	at scala.concurrent.impl.Promise$Transformation.submitWithValue(Promise.scala:429)
# 	at scala.concurrent.impl.Promise$DefaultPromise.submitWithValue(Promise.scala:338)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete0(Promise.scala:285)
# 	at scala.concurrent.impl.Promise$Transformation.run(Promise.scala:504)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl.execute(ExecutionContextImpl.scala:21)
# 	at scala.concurrent.impl.Promise$Transformation.submitWithValue(Promise.scala:429)
# 	at scala.concurrent.impl.Promise$DefaultPromise.submitWithValue(Promise.scala:338)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete0(Promise.scala:285)
# 	at scala.concurrent.impl.Promise$Transformation.run(Promise.scala:504)
# 	at scala.concurrent.ExecutionContext$parasitic$.execute(ExecutionContext.scala:222)
# 	at scala.concurrent.impl.Promise$Transformation.submitWithValue(Promise.scala:429)
# 	at scala.concurrent.impl.Promise$DefaultPromise.submitWithValue(Promise.scala:335)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete0(Promise.scala:285)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:278)
# 	at scala.concurrent.Promise.trySuccess(Promise.scala:99)
# 	at scala.concurrent.Promise.trySuccess$(Promise.scala:99)
# 	at scala.concurrent.impl.Promise$DefaultPromise.trySuccess(Promise.scala:104)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.onSuccess$1(NettyRpcEnv.scala:228)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$askAbortable$5(NettyRpcEnv.scala:242)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$askAbortable$5$adapted(NettyRpcEnv.scala:241)
# 	at scala.concurrent.impl.Promise$Transformation.run(Promise.scala:484)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl.execute(ExecutionContextImpl.scala:21)
# 	at scala.concurrent.impl.Promise$Transformation.submitWithValue(Promise.scala:429)
# 	at scala.concurrent.impl.Promise$DefaultPromise.submitWithValue(Promise.scala:338)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete0(Promise.scala:285)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:278)
# 	at scala.concurrent.Promise.complete(Promise.scala:57)
# 	at scala.concurrent.Promise.complete$(Promise.scala:56)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:104)
# 	at scala.concurrent.Promise.success(Promise.scala:91)
# 	at scala.concurrent.Promise.success$(Promise.scala:91)
# 	at scala.concurrent.impl.Promise$DefaultPromise.success(Promise.scala:104)
# 	at org.apache.spark.rpc.netty.LocalNettyRpcCallContext.send(NettyRpcCallContext.scala:50)
# 	at org.apache.spark.rpc.netty.NettyRpcCallContext.reply(NettyRpcCallContext.scala:32)
# 	at org.apache.spark.rpc.netty.RpcEndpointVerifier$$anonfun$receiveAndReply$1.applyOrElse(RpcEndpointVerifier.scala:31)
# 	... 8 more
# 25/09/08 17:55:41 WARN Executor: Issue communicating with driver in heartbeater
# org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.SparkThreadUtils$.awaitResult(SparkThreadUtils.scala:53)
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:342)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEndpointRef.askSync(RpcEndpointRef.scala:101)
# 	at org.apache.spark.rpc.RpcEndpointRef.askSync(RpcEndpointRef.scala:85)
# 	at org.apache.spark.storage.BlockManagerMaster.registerBlockManager(BlockManagerMaster.scala:81)
# 	at org.apache.spark.storage.BlockManager.reregister(BlockManager.scala:669)
# 	at org.apache.spark.executor.Executor.reportHeartBeat(Executor.scala:1296)
# 	at org.apache.spark.executor.Executor.$anonfun$heartbeater$1(Executor.scala:307)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.scala:18)
# 	at org.apache.spark.util.Utils$.logUncaughtExceptions(Utils.scala:1937)
# 	at org.apache.spark.Heartbeater$$anon$1.run(Heartbeater.scala:46)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Unknown Source)
# 	at java.base/java.util.concurrent.FutureTask.runAndReset(Unknown Source)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(Unknown Source)
# 	at java.base/java.lang.Thread.run(Unknown Source)
# Caused by: org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.SparkThreadUtils$.awaitResult(SparkThreadUtils.scala:53)
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:342)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRefByURI(RpcEnv.scala:102)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRef(RpcEnv.scala:110)
# 	at org.apache.spark.util.RpcUtils$.makeDriverRef(RpcUtils.scala:36)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.driverEndpoint$lzycompute(BlockManagerMasterEndpoint.scala:132)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$driverEndpoint(BlockManagerMasterEndpoint.scala:131)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$lzycompute$1(BlockManagerMasterEndpoint.scala:700)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$1(BlockManagerMasterEndpoint.scala:699)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$register(BlockManagerMasterEndpoint.scala:739)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint$$anonfun$receiveAndReply$1.applyOrElse(BlockManagerMasterEndpoint.scala:141)
# 	at org.apache.spark.rpc.netty.Inbox.$anonfun$process$1(Inbox.scala:104)
# 	at org.apache.spark.rpc.netty.Inbox.safelyCall(Inbox.scala:216)
# 	at org.apache.spark.rpc.netty.Inbox.process(Inbox.scala:101)
# 	at org.apache.spark.rpc.netty.MessageLoop.org$apache$spark$rpc$netty$MessageLoop$$receiveLoop(MessageLoop.scala:76)
# 	at org.apache.spark.rpc.netty.MessageLoop$$anon$1.run(MessageLoop.scala:42)
# 	... 3 more
# Caused by: org.apache.spark.rpc.RpcEndpointNotFoundException: Cannot find endpoint: spark://CoarseGrainedScheduler@192.168.0.45:53646
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1(NettyRpcEnv.scala:151)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1$adapted(NettyRpcEnv.scala:147)
# 	at scala.concurrent.impl.Promise$Transformation.run(Promise.scala:470)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl.execute(ExecutionContextImpl.scala:21)
# 	at scala.concurrent.impl.Promise$Transformation.submitWithValue(Promise.scala:429)
# 	at scala.concurrent.impl.Promise$DefaultPromise.submitWithValue(Promise.scala:338)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete0(Promise.scala:285)
# 	at scala.concurrent.impl.Promise$Transformation.run(Promise.scala:504)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl.execute(ExecutionContextImpl.scala:21)
# 	at scala.concurrent.impl.Promise$Transformation.submitWithValue(Promise.scala:429)
# 	at scala.concurrent.impl.Promise$DefaultPromise.submitWithValue(Promise.scala:338)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete0(Promise.scala:285)
# 	at scala.concurrent.impl.Promise$Transformation.run(Promise.scala:504)
# 	at scala.concurrent.ExecutionContext$parasitic$.execute(ExecutionContext.scala:222)
# 	at scala.concurrent.impl.Promise$Transformation.submitWithValue(Promise.scala:429)
# 	at scala.concurrent.impl.Promise$DefaultPromise.submitWithValue(Promise.scala:335)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete0(Promise.scala:285)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:278)
# 	at scala.concurrent.Promise.trySuccess(Promise.scala:99)
# 	at scala.concurrent.Promise.trySuccess$(Promise.scala:99)
# 	at scala.concurrent.impl.Promise$DefaultPromise.trySuccess(Promise.scala:104)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.onSuccess$1(NettyRpcEnv.scala:228)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$askAbortable$5(NettyRpcEnv.scala:242)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$askAbortable$5$adapted(NettyRpcEnv.scala:241)
# 	at scala.concurrent.impl.Promise$Transformation.run(Promise.scala:484)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl.execute(ExecutionContextImpl.scala:21)
# 	at scala.concurrent.impl.Promise$Transformation.submitWithValue(Promise.scala:429)
# 	at scala.concurrent.impl.Promise$DefaultPromise.submitWithValue(Promise.scala:338)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete0(Promise.scala:285)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:278)
# 	at scala.concurrent.Promise.complete(Promise.scala:57)
# 	at scala.concurrent.Promise.complete$(Promise.scala:56)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:104)
# 	at scala.concurrent.Promise.success(Promise.scala:91)
# 	at scala.concurrent.Promise.success$(Promise.scala:91)
# 	at scala.concurrent.impl.Promise$DefaultPromise.success(Promise.scala:104)
# 	at org.apache.spark.rpc.netty.LocalNettyRpcCallContext.send(NettyRpcCallContext.scala:50)
# 	at org.apache.spark.rpc.netty.NettyRpcCallContext.reply(NettyRpcCallContext.scala:32)
# 	at org.apache.spark.rpc.netty.RpcEndpointVerifier$$anonfun$receiveAndReply$1.applyOrElse(RpcEndpointVerifier.scala:31)
# 	... 8 more
# 25/09/08 17:55:41 ERROR Inbox: Ignoring error
# org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.SparkThreadUtils$.awaitResult(SparkThreadUtils.scala:53)
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:342)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRefByURI(RpcEnv.scala:102)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRef(RpcEnv.scala:110)
# 	at org.apache.spark.util.RpcUtils$.makeDriverRef(RpcUtils.scala:36)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.driverEndpoint$lzycompute(BlockManagerMasterEndpoint.scala:132)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$driverEndpoint(BlockManagerMasterEndpoint.scala:131)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$lzycompute$1(BlockManagerMasterEndpoint.scala:700)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$1(BlockManagerMasterEndpoint.scala:699)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$register(BlockManagerMasterEndpoint.scala:739)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint$$anonfun$receiveAndReply$1.applyOrElse(BlockManagerMasterEndpoint.scala:141)
# 	at org.apache.spark.rpc.netty.Inbox.$anonfun$process$1(Inbox.scala:104)
# 	at org.apache.spark.rpc.netty.Inbox.safelyCall(Inbox.scala:216)
# 	at org.apache.spark.rpc.netty.Inbox.process(Inbox.scala:101)
# 	at org.apache.spark.rpc.netty.MessageLoop.org$apache$spark$rpc$netty$MessageLoop$$receiveLoop(MessageLoop.scala:76)
# 	at org.apache.spark.rpc.netty.MessageLoop$$anon$1.run(MessageLoop.scala:42)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(Unknown Source)
# 	at java.base/java.lang.Thread.run(Unknown Source)
# Caused by: org.apache.spark.rpc.RpcEndpointNotFoundException: Cannot find endpoint: spark://CoarseGrainedScheduler@192.168.0.45:53646
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1(NettyRpcEnv.scala:151)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1$adapted(NettyRpcEnv.scala:147)
# 	at scala.concurrent.impl.Promise$Transformation.run(Promise.scala:470)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl.execute(ExecutionContextImpl.scala:21)
# 	at scala.concurrent.impl.Promise$Transformation.submitWithValue(Promise.scala:429)
# 	at scala.concurrent.impl.Promise$DefaultPromise.submitWithValue(Promise.scala:338)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete0(Promise.scala:285)
# 	at scala.concurrent.impl.Promise$Transformation.run(Promise.scala:504)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl.execute(ExecutionContextImpl.scala:21)
# 	at scala.concurrent.impl.Promise$Transformation.submitWithValue(Promise.scala:429)
# 	at scala.concurrent.impl.Promise$DefaultPromise.submitWithValue(Promise.scala:338)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete0(Promise.scala:285)
# 	at scala.concurrent.impl.Promise$Transformation.run(Promise.scala:504)
# 	at scala.concurrent.ExecutionContext$parasitic$.execute(ExecutionContext.scala:222)
# 	at scala.concurrent.impl.Promise$Transformation.submitWithValue(Promise.scala:429)
# 	at scala.concurrent.impl.Promise$DefaultPromise.submitWithValue(Promise.scala:335)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete0(Promise.scala:285)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:278)
# 	at scala.concurrent.Promise.trySuccess(Promise.scala:99)
# 	at scala.concurrent.Promise.trySuccess$(Promise.scala:99)
# 	at scala.concurrent.impl.Promise$DefaultPromise.trySuccess(Promise.scala:104)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.onSuccess$1(NettyRpcEnv.scala:228)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$askAbortable$5(NettyRpcEnv.scala:242)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$askAbortable$5$adapted(NettyRpcEnv.scala:241)
# 	at scala.concurrent.impl.Promise$Transformation.run(Promise.scala:484)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl.execute(ExecutionContextImpl.scala:21)
# 	at scala.concurrent.impl.Promise$Transformation.submitWithValue(Promise.scala:429)
# 	at scala.concurrent.impl.Promise$DefaultPromise.submitWithValue(Promise.scala:338)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete0(Promise.scala:285)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:278)
# 	at scala.concurrent.Promise.complete(Promise.scala:57)
# 	at scala.concurrent.Promise.complete$(Promise.scala:56)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:104)
# 	at scala.concurrent.Promise.success(Promise.scala:91)
# 	at scala.concurrent.Promise.success$(Promise.scala:91)
# 	at scala.concurrent.impl.Promise$DefaultPromise.success(Promise.scala:104)
# 	at org.apache.spark.rpc.netty.LocalNettyRpcCallContext.send(NettyRpcCallContext.scala:50)
# 	at org.apache.spark.rpc.netty.NettyRpcCallContext.reply(NettyRpcCallContext.scala:32)
# 	at org.apache.spark.rpc.netty.RpcEndpointVerifier$$anonfun$receiveAndReply$1.applyOrElse(RpcEndpointVerifier.scala:31)
# 	... 8 more
# 25/09/08 18:12:19 ERROR Inbox: Ignoring error
# org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.SparkThreadUtils$.awaitResult(SparkThreadUtils.scala:53)
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:342)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRefByURI(RpcEnv.scala:102)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRef(RpcEnv.scala:110)
# 	at org.apache.spark.util.RpcUtils$.makeDriverRef(RpcUtils.scala:36)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.driverEndpoint$lzycompute(BlockManagerMasterEndpoint.scala:132)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$driverEndpoint(BlockManagerMasterEndpoint.scala:131)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$lzycompute$1(BlockManagerMasterEndpoint.scala:700)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$1(BlockManagerMasterEndpoint.scala:699)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$register(BlockManagerMasterEndpoint.scala:739)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint$$anonfun$receiveAndReply$1.applyOrElse(BlockManagerMasterEndpoint.scala:141)
# 	at org.apache.spark.rpc.netty.Inbox.$anonfun$process$1(Inbox.scala:104)
# 	at org.apache.spark.rpc.netty.Inbox.safelyCall(Inbox.scala:216)
# 	at org.apache.spark.rpc.netty.Inbox.process(Inbox.scala:101)
# 	at org.apache.spark.rpc.netty.MessageLoop.org$apache$spark$rpc$netty$MessageLoop$$receiveLoop(MessageLoop.scala:76)
# 	at org.apache.spark.rpc.netty.MessageLoop$$anon$1.run(MessageLoop.scala:42)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(Unknown Source)
# 	at java.base/java.lang.Thread.run(Unknown Source)
# Caused by: org.apache.spark.rpc.RpcEndpointNotFoundException: Cannot find endpoint: spark://CoarseGrainedScheduler@192.168.0.45:53646
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1(NettyRpcEnv.scala:151)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1$adapted(NettyRpcEnv.scala:147)
# 	at scala.concurrent.impl.Promise$Transformation.run(Promise.scala:470)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl.execute(ExecutionContextImpl.scala:21)
# 	at scala.concurrent.impl.Promise$Transformation.submitWithValue(Promise.scala:429)
# 	at scala.concurrent.impl.Promise$DefaultPromise.submitWithValue(Promise.scala:338)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete0(Promise.scala:285)
# 	at scala.concurrent.impl.Promise$Transformation.run(Promise.scala:504)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl.execute(ExecutionContextImpl.scala:21)
# 	at scala.concurrent.impl.Promise$Transformation.submitWithValue(Promise.scala:429)
# 	at scala.concurrent.impl.Promise$DefaultPromise.submitWithValue(Promise.scala:338)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete0(Promise.scala:285)
# 	at scala.concurrent.impl.Promise$Transformation.run(Promise.scala:504)
# 	at scala.concurrent.ExecutionContext$parasitic$.execute(ExecutionContext.scala:222)
# 	at scala.concurrent.impl.Promise$Transformation.submitWithValue(Promise.scala:429)
# 	at scala.concurrent.impl.Promise$DefaultPromise.submitWithValue(Promise.scala:335)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete0(Promise.scala:285)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:278)
# 	at scala.concurrent.Promise.trySuccess(Promise.scala:99)
# 	at scala.concurrent.Promise.trySuccess$(Promise.scala:99)
# 	at scala.concurrent.impl.Promise$DefaultPromise.trySuccess(Promise.scala:104)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.onSuccess$1(NettyRpcEnv.scala:228)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$askAbortable$5(NettyRpcEnv.scala:242)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$askAbortable$5$adapted(NettyRpcEnv.scala:241)
# 	at scala.concurrent.impl.Promise$Transformation.run(Promise.scala:484)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl.execute(ExecutionContextImpl.scala:21)
# 	at scala.concurrent.impl.Promise$Transformation.submitWithValue(Promise.scala:429)
# 	at scala.concurrent.impl.Promise$DefaultPromise.submitWithValue(Promise.scala:338)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete0(Promise.scala:285)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:278)
# 	at scala.concurrent.Promise.complete(Promise.scala:57)
# 	at scala.concurrent.Promise.complete$(Promise.scala:56)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:104)
# 	at scala.concurrent.Promise.success(Promise.scala:91)
# 	at scala.concurrent.Promise.success$(Promise.scala:91)
# 	at scala.concurrent.impl.Promise$DefaultPromise.success(Promise.scala:104)
# 	at org.apache.spark.rpc.netty.LocalNettyRpcCallContext.send(NettyRpcCallContext.scala:50)
# 	at org.apache.spark.rpc.netty.NettyRpcCallContext.reply(NettyRpcCallContext.scala:32)
# 	at org.apache.spark.rpc.netty.RpcEndpointVerifier$$anonfun$receiveAndReply$1.applyOrElse(RpcEndpointVerifier.scala:31)
# 	... 8 more
# 25/09/08 18:12:19 WARN Executor: Issue communicating with driver in heartbeater
# org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.SparkThreadUtils$.awaitResult(SparkThreadUtils.scala:53)
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:342)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEndpointRef.askSync(RpcEndpointRef.scala:101)
# 	at org.apache.spark.rpc.RpcEndpointRef.askSync(RpcEndpointRef.scala:85)
# 	at org.apache.spark.storage.BlockManagerMaster.registerBlockManager(BlockManagerMaster.scala:81)
# 	at org.apache.spark.storage.BlockManager.reregister(BlockManager.scala:669)
# 	at org.apache.spark.executor.Executor.reportHeartBeat(Executor.scala:1296)
# 	at org.apache.spark.executor.Executor.$anonfun$heartbeater$1(Executor.scala:307)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.scala:18)
# 	at org.apache.spark.util.Utils$.logUncaughtExceptions(Utils.scala:1937)
# 	at org.apache.spark.Heartbeater$$anon$1.run(Heartbeater.scala:46)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Unknown Source)
# 	at java.base/java.util.concurrent.FutureTask.runAndReset(Unknown Source)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(Unknown Source)
# 	at java.base/java.lang.Thread.run(Unknown Source)
# Caused by: org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.SparkThreadUtils$.awaitResult(SparkThreadUtils.scala:53)
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:342)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRefByURI(RpcEnv.scala:102)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRef(RpcEnv.scala:110)
# 	at org.apache.spark.util.RpcUtils$.makeDriverRef(RpcUtils.scala:36)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.driverEndpoint$lzycompute(BlockManagerMasterEndpoint.scala:132)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$driverEndpoint(BlockManagerMasterEndpoint.scala:131)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$lzycompute$1(BlockManagerMasterEndpoint.scala:700)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$1(BlockManagerMasterEndpoint.scala:699)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$register(BlockManagerMasterEndpoint.scala:739)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint$$anonfun$receiveAndReply$1.applyOrElse(BlockManagerMasterEndpoint.scala:141)
# 	at org.apache.spark.rpc.netty.Inbox.$anonfun$process$1(Inbox.scala:104)
# 	at org.apache.spark.rpc.netty.Inbox.safelyCall(Inbox.scala:216)
# 	at org.apache.spark.rpc.netty.Inbox.process(Inbox.scala:101)
# 	at org.apache.spark.rpc.netty.MessageLoop.org$apache$spark$rpc$netty$MessageLoop$$receiveLoop(MessageLoop.scala:76)
# 	at org.apache.spark.rpc.netty.MessageLoop$$anon$1.run(MessageLoop.scala:42)
# 	... 3 more
# Caused by: org.apache.spark.rpc.RpcEndpointNotFoundException: Cannot find endpoint: spark://CoarseGrainedScheduler@192.168.0.45:53646
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1(NettyRpcEnv.scala:151)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1$adapted(NettyRpcEnv.scala:147)
# 	at scala.concurrent.impl.Promise$Transformation.run(Promise.scala:470)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl.execute(ExecutionContextImpl.scala:21)
# 	at scala.concurrent.impl.Promise$Transformation.submitWithValue(Promise.scala:429)
# 	at scala.concurrent.impl.Promise$DefaultPromise.submitWithValue(Promise.scala:338)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete0(Promise.scala:285)
# 	at scala.concurrent.impl.Promise$Transformation.run(Promise.scala:504)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl.execute(ExecutionContextImpl.scala:21)
# 	at scala.concurrent.impl.Promise$Transformation.submitWithValue(Promise.scala:429)
# 	at scala.concurrent.impl.Promise$DefaultPromise.submitWithValue(Promise.scala:338)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete0(Promise.scala:285)
# 	at scala.concurrent.impl.Promise$Transformation.run(Promise.scala:504)
# 	at scala.concurrent.ExecutionContext$parasitic$.execute(ExecutionContext.scala:222)
# 	at scala.concurrent.impl.Promise$Transformation.submitWithValue(Promise.scala:429)
# 	at scala.concurrent.impl.Promise$DefaultPromise.submitWithValue(Promise.scala:335)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete0(Promise.scala:285)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:278)
# 	at scala.concurrent.Promise.trySuccess(Promise.scala:99)
# 	at scala.concurrent.Promise.trySuccess$(Promise.scala:99)
# 	at scala.concurrent.impl.Promise$DefaultPromise.trySuccess(Promise.scala:104)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.onSuccess$1(NettyRpcEnv.scala:228)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$askAbortable$5(NettyRpcEnv.scala:242)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$askAbortable$5$adapted(NettyRpcEnv.scala:241)
# 	at scala.concurrent.impl.Promise$Transformation.run(Promise.scala:484)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl.execute(ExecutionContextImpl.scala:21)
# 	at scala.concurrent.impl.Promise$Transformation.submitWithValue(Promise.scala:429)
# 	at scala.concurrent.impl.Promise$DefaultPromise.submitWithValue(Promise.scala:338)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete0(Promise.scala:285)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:278)
# 	at scala.concurrent.Promise.complete(Promise.scala:57)
# 	at scala.concurrent.Promise.complete$(Promise.scala:56)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:104)
# 	at scala.concurrent.Promise.success(Promise.scala:91)
# 	at scala.concurrent.Promise.success$(Promise.scala:91)
# 	at scala.concurrent.impl.Promise$DefaultPromise.success(Promise.scala:104)
# 	at org.apache.spark.rpc.netty.LocalNettyRpcCallContext.send(NettyRpcCallContext.scala:50)
# 	at org.apache.spark.rpc.netty.NettyRpcCallContext.reply(NettyRpcCallContext.scala:32)
# 	at org.apache.spark.rpc.netty.RpcEndpointVerifier$$anonfun$receiveAndReply$1.applyOrElse(RpcEndpointVerifier.scala:31)
# 	... 8 more
# 25/09/08 18:30:16 WARN Executor: Issue communicating with driver in heartbeater
# org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.SparkThreadUtils$.awaitResult(SparkThreadUtils.scala:53)
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:342)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEndpointRef.askSync(RpcEndpointRef.scala:101)
# 	at org.apache.spark.rpc.RpcEndpointRef.askSync(RpcEndpointRef.scala:85)
# 	at org.apache.spark.storage.BlockManagerMaster.registerBlockManager(BlockManagerMaster.scala:81)
# 	at org.apache.spark.storage.BlockManager.reregister(BlockManager.scala:669)
# 	at org.apache.spark.executor.Executor.reportHeartBeat(Executor.scala:1296)
# 	at org.apache.spark.executor.Executor.$anonfun$heartbeater$1(Executor.scala:307)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.scala:18)
# 	at org.apache.spark.util.Utils$.logUncaughtExceptions(Utils.scala:1937)
# 	at org.apache.spark.Heartbeater$$anon$1.run(Heartbeater.scala:46)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Unknown Source)
# 	at java.base/java.util.concurrent.FutureTask.runAndReset(Unknown Source)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(Unknown Source)
# 	at java.base/java.lang.Thread.run(Unknown Source)
# Caused by: org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.SparkThreadUtils$.awaitResult(SparkThreadUtils.scala:53)
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:342)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRefByURI(RpcEnv.scala:102)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRef(RpcEnv.scala:110)
# 	at org.apache.spark.util.RpcUtils$.makeDriverRef(RpcUtils.scala:36)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.driverEndpoint$lzycompute(BlockManagerMasterEndpoint.scala:132)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$driverEndpoint(BlockManagerMasterEndpoint.scala:131)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$lzycompute$1(BlockManagerMasterEndpoint.scala:700)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$1(BlockManagerMasterEndpoint.scala:699)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$register(BlockManagerMasterEndpoint.scala:739)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint$$anonfun$receiveAndReply$1.applyOrElse(BlockManagerMasterEndpoint.scala:141)
# 	at org.apache.spark.rpc.netty.Inbox.$anonfun$process$1(Inbox.scala:104)
# 	at org.apache.spark.rpc.netty.Inbox.safelyCall(Inbox.scala:216)
# 	at org.apache.spark.rpc.netty.Inbox.process(Inbox.scala:101)
# 	at org.apache.spark.rpc.netty.MessageLoop.org$apache$spark$rpc$netty$MessageLoop$$receiveLoop(MessageLoop.scala:76)
# 	at org.apache.spark.rpc.netty.MessageLoop$$anon$1.run(MessageLoop.scala:42)
# 	... 3 more
# Caused by: org.apache.spark.rpc.RpcEndpointNotFoundException: Cannot find endpoint: spark://CoarseGrainedScheduler@192.168.0.45:53646
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1(NettyRpcEnv.scala:151)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1$adapted(NettyRpcEnv.scala:147)
# 	at scala.concurrent.impl.Promise$Transformation.run(Promise.scala:470)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl.execute(ExecutionContextImpl.scala:21)
# 	at scala.concurrent.impl.Promise$Transformation.submitWithValue(Promise.scala:429)
# 	at scala.concurrent.impl.Promise$DefaultPromise.submitWithValue(Promise.scala:338)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete0(Promise.scala:285)
# 	at scala.concurrent.impl.Promise$Transformation.run(Promise.scala:504)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl.execute(ExecutionContextImpl.scala:21)
# 	at scala.concurrent.impl.Promise$Transformation.submitWithValue(Promise.scala:429)
# 	at scala.concurrent.impl.Promise$DefaultPromise.submitWithValue(Promise.scala:338)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete0(Promise.scala:285)
# 	at scala.concurrent.impl.Promise$Transformation.run(Promise.scala:504)
# 	at scala.concurrent.ExecutionContext$parasitic$.execute(ExecutionContext.scala:222)
# 	at scala.concurrent.impl.Promise$Transformation.submitWithValue(Promise.scala:429)
# 	at scala.concurrent.impl.Promise$DefaultPromise.submitWithValue(Promise.scala:335)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete0(Promise.scala:285)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:278)
# 	at scala.concurrent.Promise.trySuccess(Promise.scala:99)
# 	at scala.concurrent.Promise.trySuccess$(Promise.scala:99)
# 	at scala.concurrent.impl.Promise$DefaultPromise.trySuccess(Promise.scala:104)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.onSuccess$1(NettyRpcEnv.scala:228)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$askAbortable$5(NettyRpcEnv.scala:242)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$askAbortable$5$adapted(NettyRpcEnv.scala:241)
# 	at scala.concurrent.impl.Promise$Transformation.run(Promise.scala:484)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl.execute(ExecutionContextImpl.scala:21)
# 	at scala.concurrent.impl.Promise$Transformation.submitWithValue(Promise.scala:429)
# 	at scala.concurrent.impl.Promise$DefaultPromise.submitWithValue(Promise.scala:338)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete0(Promise.scala:285)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:278)
# 	at scala.concurrent.Promise.complete(Promise.scala:57)
# 	at scala.concurrent.Promise.complete$(Promise.scala:56)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:104)
# 	at scala.concurrent.Promise.success(Promise.scala:91)
# 	at scala.concurrent.Promise.success$(Promise.scala:91)
# 	at scala.concurrent.impl.Promise$DefaultPromise.success(Promise.scala:104)
# 	at org.apache.spark.rpc.netty.LocalNettyRpcCallContext.send(NettyRpcCallContext.scala:50)
# 	at org.apache.spark.rpc.netty.NettyRpcCallContext.reply(NettyRpcCallContext.scala:32)
# 	at org.apache.spark.rpc.netty.RpcEndpointVerifier$$anonfun$receiveAndReply$1.applyOrElse(RpcEndpointVerifier.scala:31)
# 	... 8 more
# 25/09/08 18:30:16 ERROR Inbox: Ignoring error
# org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.SparkThreadUtils$.awaitResult(SparkThreadUtils.scala:53)
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:342)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRefByURI(RpcEnv.scala:102)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRef(RpcEnv.scala:110)
# 	at org.apache.spark.util.RpcUtils$.makeDriverRef(RpcUtils.scala:36)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.driverEndpoint$lzycompute(BlockManagerMasterEndpoint.scala:132)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$driverEndpoint(BlockManagerMasterEndpoint.scala:131)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$lzycompute$1(BlockManagerMasterEndpoint.scala:700)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$1(BlockManagerMasterEndpoint.scala:699)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$register(BlockManagerMasterEndpoint.scala:739)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint$$anonfun$receiveAndReply$1.applyOrElse(BlockManagerMasterEndpoint.scala:141)
# 	at org.apache.spark.rpc.netty.Inbox.$anonfun$process$1(Inbox.scala:104)
# 	at org.apache.spark.rpc.netty.Inbox.safelyCall(Inbox.scala:216)
# 	at org.apache.spark.rpc.netty.Inbox.process(Inbox.scala:101)
# 	at org.apache.spark.rpc.netty.MessageLoop.org$apache$spark$rpc$netty$MessageLoop$$receiveLoop(MessageLoop.scala:76)
# 	at org.apache.spark.rpc.netty.MessageLoop$$anon$1.run(MessageLoop.scala:42)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(Unknown Source)
# 	at java.base/java.lang.Thread.run(Unknown Source)
# Caused by: org.apache.spark.rpc.RpcEndpointNotFoundException: Cannot find endpoint: spark://CoarseGrainedScheduler@192.168.0.45:53646
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1(NettyRpcEnv.scala:151)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1$adapted(NettyRpcEnv.scala:147)
# 	at scala.concurrent.impl.Promise$Transformation.run(Promise.scala:470)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl.execute(ExecutionContextImpl.scala:21)
# 	at scala.concurrent.impl.Promise$Transformation.submitWithValue(Promise.scala:429)
# 	at scala.concurrent.impl.Promise$DefaultPromise.submitWithValue(Promise.scala:338)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete0(Promise.scala:285)
# 	at scala.concurrent.impl.Promise$Transformation.run(Promise.scala:504)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl.execute(ExecutionContextImpl.scala:21)
# 	at scala.concurrent.impl.Promise$Transformation.submitWithValue(Promise.scala:429)
# 	at scala.concurrent.impl.Promise$DefaultPromise.submitWithValue(Promise.scala:338)
# ...
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl.execute(ExecutionContextImpl.scala:21)
# 	at scala.concurrent.impl.Promise$Transformation.submitWithValue(Promise.scala:429)
# 	at scala.concurrent.impl.Promise$DefaultPromise.submitWithValue(Promise.scala:338)
# 	at scala.concurrent.impl.Promise$DefaultPromise.dispatchOrAddCallbacks(Promise.scala:312)
# 	at scala.concurrent.impl.Promise$DefaultPromise.flatMap(Promise.scala:176)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.asyncSetupEndpointRefByURI(NettyRpcEnv.scala:153)
# 	... 17 more
# 25/09/09 08:09:27 ERROR Inbox: Ignoring error
# org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.SparkThreadUtils$.awaitResult(SparkThreadUtils.scala:53)
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:342)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRefByURI(RpcEnv.scala:102)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRef(RpcEnv.scala:110)
# 	at org.apache.spark.util.RpcUtils$.makeDriverRef(RpcUtils.scala:36)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.driverEndpoint$lzycompute(BlockManagerMasterEndpoint.scala:132)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$driverEndpoint(BlockManagerMasterEndpoint.scala:131)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$lzycompute$1(BlockManagerMasterEndpoint.scala:700)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$1(BlockManagerMasterEndpoint.scala:699)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$register(BlockManagerMasterEndpoint.scala:739)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint$$anonfun$receiveAndReply$1.applyOrElse(BlockManagerMasterEndpoint.scala:141)
# 	at org.apache.spark.rpc.netty.Inbox.$anonfun$process$1(Inbox.scala:104)
# 	at org.apache.spark.rpc.netty.Inbox.safelyCall(Inbox.scala:216)
# 	at org.apache.spark.rpc.netty.Inbox.process(Inbox.scala:101)
# 	at org.apache.spark.rpc.netty.MessageLoop.org$apache$spark$rpc$netty$MessageLoop$$receiveLoop(MessageLoop.scala:76)
# 	at org.apache.spark.rpc.netty.MessageLoop$$anon$1.run(MessageLoop.scala:42)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(Unknown Source)
# 	at java.base/java.lang.Thread.run(Unknown Source)
# Caused by: org.apache.spark.rpc.RpcEndpointNotFoundException: Cannot find endpoint: spark://CoarseGrainedScheduler@192.168.0.45:53646
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1(NettyRpcEnv.scala:151)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1$adapted(NettyRpcEnv.scala:147)
# 	at scala.concurrent.impl.Promise$Transformation.run(Promise.scala:470)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl.execute(ExecutionContextImpl.scala:21)
# 	at scala.concurrent.impl.Promise$Transformation.submitWithValue(Promise.scala:429)
# 	at scala.concurrent.impl.Promise$DefaultPromise.submitWithValue(Promise.scala:338)
# 	at scala.concurrent.impl.Promise$DefaultPromise.dispatchOrAddCallbacks(Promise.scala:312)
# 	at scala.concurrent.impl.Promise$DefaultPromise.flatMap(Promise.scala:176)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.asyncSetupEndpointRefByURI(NettyRpcEnv.scala:153)
# 	... 17 more
# 25/09/09 08:09:37 WARN Executor: Issue communicating with driver in heartbeater
# org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.SparkThreadUtils$.awaitResult(SparkThreadUtils.scala:53)
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:342)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEndpointRef.askSync(RpcEndpointRef.scala:101)
# 	at org.apache.spark.rpc.RpcEndpointRef.askSync(RpcEndpointRef.scala:85)
# 	at org.apache.spark.storage.BlockManagerMaster.registerBlockManager(BlockManagerMaster.scala:81)
# 	at org.apache.spark.storage.BlockManager.reregister(BlockManager.scala:669)
# 	at org.apache.spark.executor.Executor.reportHeartBeat(Executor.scala:1296)
# 	at org.apache.spark.executor.Executor.$anonfun$heartbeater$1(Executor.scala:307)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.scala:18)
# 	at org.apache.spark.util.Utils$.logUncaughtExceptions(Utils.scala:1937)
# 	at org.apache.spark.Heartbeater$$anon$1.run(Heartbeater.scala:46)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Unknown Source)
# 	at java.base/java.util.concurrent.FutureTask.runAndReset(Unknown Source)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(Unknown Source)
# 	at java.base/java.lang.Thread.run(Unknown Source)
# Caused by: org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.SparkThreadUtils$.awaitResult(SparkThreadUtils.scala:53)
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:342)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRefByURI(RpcEnv.scala:102)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRef(RpcEnv.scala:110)
# 	at org.apache.spark.util.RpcUtils$.makeDriverRef(RpcUtils.scala:36)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.driverEndpoint$lzycompute(BlockManagerMasterEndpoint.scala:132)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$driverEndpoint(BlockManagerMasterEndpoint.scala:131)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$lzycompute$1(BlockManagerMasterEndpoint.scala:700)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$1(BlockManagerMasterEndpoint.scala:699)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$register(BlockManagerMasterEndpoint.scala:739)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint$$anonfun$receiveAndReply$1.applyOrElse(BlockManagerMasterEndpoint.scala:141)
# 	at org.apache.spark.rpc.netty.Inbox.$anonfun$process$1(Inbox.scala:104)
# 	at org.apache.spark.rpc.netty.Inbox.safelyCall(Inbox.scala:216)
# 	at org.apache.spark.rpc.netty.Inbox.process(Inbox.scala:101)
# 	at org.apache.spark.rpc.netty.MessageLoop.org$apache$spark$rpc$netty$MessageLoop$$receiveLoop(MessageLoop.scala:76)
# 	at org.apache.spark.rpc.netty.MessageLoop$$anon$1.run(MessageLoop.scala:42)
# 	... 3 more
# Caused by: org.apache.spark.rpc.RpcEndpointNotFoundException: Cannot find endpoint: spark://CoarseGrainedScheduler@192.168.0.45:53646
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1(NettyRpcEnv.scala:151)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1$adapted(NettyRpcEnv.scala:147)
# 	at scala.concurrent.impl.Promise$Transformation.run(Promise.scala:470)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl.execute(ExecutionContextImpl.scala:21)
# 	at scala.concurrent.impl.Promise$Transformation.submitWithValue(Promise.scala:429)
# 	at scala.concurrent.impl.Promise$DefaultPromise.submitWithValue(Promise.scala:338)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete0(Promise.scala:285)
# 	at scala.concurrent.impl.Promise$Transformation.run(Promise.scala:504)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl.execute(ExecutionContextImpl.scala:21)
# 	at scala.concurrent.impl.Promise$Transformation.submitWithValue(Promise.scala:429)
# 	at scala.concurrent.impl.Promise$DefaultPromise.submitWithValue(Promise.scala:338)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete0(Promise.scala:285)
# 	at scala.concurrent.impl.Promise$Transformation.run(Promise.scala:504)
# 	at scala.concurrent.ExecutionContext$parasitic$.execute(ExecutionContext.scala:222)
# 	at scala.concurrent.impl.Promise$Transformation.submitWithValue(Promise.scala:429)
# 	at scala.concurrent.impl.Promise$DefaultPromise.submitWithValue(Promise.scala:335)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete0(Promise.scala:285)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:278)
# 	at scala.concurrent.Promise.trySuccess(Promise.scala:99)
# 	at scala.concurrent.Promise.trySuccess$(Promise.scala:99)
# 	at scala.concurrent.impl.Promise$DefaultPromise.trySuccess(Promise.scala:104)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.onSuccess$1(NettyRpcEnv.scala:228)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$askAbortable$5(NettyRpcEnv.scala:242)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$askAbortable$5$adapted(NettyRpcEnv.scala:241)
# 	at scala.concurrent.impl.Promise$Transformation.run(Promise.scala:484)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl.execute(ExecutionContextImpl.scala:21)
# 	at scala.concurrent.impl.Promise$Transformation.submitWithValue(Promise.scala:429)
# 	at scala.concurrent.impl.Promise$DefaultPromise.submitWithValue(Promise.scala:338)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete0(Promise.scala:285)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:278)
# 	at scala.concurrent.Promise.complete(Promise.scala:57)
# 	at scala.concurrent.Promise.complete$(Promise.scala:56)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:104)
# 	at scala.concurrent.Promise.success(Promise.scala:91)
# 	at scala.concurrent.Promise.success$(Promise.scala:91)
# 	at scala.concurrent.impl.Promise$DefaultPromise.success(Promise.scala:104)
# 	at org.apache.spark.rpc.netty.LocalNettyRpcCallContext.send(NettyRpcCallContext.scala:50)
# 	at org.apache.spark.rpc.netty.NettyRpcCallContext.reply(NettyRpcCallContext.scala:32)
# 	at org.apache.spark.rpc.netty.RpcEndpointVerifier$$anonfun$receiveAndReply$1.applyOrElse(RpcEndpointVerifier.scala:31)
# 	... 8 more
# 25/09/09 08:09:37 ERROR Inbox: Ignoring error
# org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.SparkThreadUtils$.awaitResult(SparkThreadUtils.scala:53)
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:342)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRefByURI(RpcEnv.scala:102)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRef(RpcEnv.scala:110)
# 	at org.apache.spark.util.RpcUtils$.makeDriverRef(RpcUtils.scala:36)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.driverEndpoint$lzycompute(BlockManagerMasterEndpoint.scala:132)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$driverEndpoint(BlockManagerMasterEndpoint.scala:131)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$lzycompute$1(BlockManagerMasterEndpoint.scala:700)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$1(BlockManagerMasterEndpoint.scala:699)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$register(BlockManagerMasterEndpoint.scala:739)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint$$anonfun$receiveAndReply$1.applyOrElse(BlockManagerMasterEndpoint.scala:141)
# 	at org.apache.spark.rpc.netty.Inbox.$anonfun$process$1(Inbox.scala:104)
# 	at org.apache.spark.rpc.netty.Inbox.safelyCall(Inbox.scala:216)
# 	at org.apache.spark.rpc.netty.Inbox.process(Inbox.scala:101)
# 	at org.apache.spark.rpc.netty.MessageLoop.org$apache$spark$rpc$netty$MessageLoop$$receiveLoop(MessageLoop.scala:76)
# 	at org.apache.spark.rpc.netty.MessageLoop$$anon$1.run(MessageLoop.scala:42)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(Unknown Source)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(Unknown Source)
# 	at java.base/java.lang.Thread.run(Unknown Source)
# Caused by: org.apache.spark.rpc.RpcEndpointNotFoundException: Cannot find endpoint: spark://CoarseGrainedScheduler@192.168.0.45:53646
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1(NettyRpcEnv.scala:151)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1$adapted(NettyRpcEnv.scala:147)
# 	at scala.concurrent.impl.Promise$Transformation.run(Promise.scala:470)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl.execute(ExecutionContextImpl.scala:21)
# 	at scala.concurrent.impl.Promise$Transformation.submitWithValue(Promise.scala:429)
# 	at scala.concurrent.impl.Promise$DefaultPromise.submitWithValue(Promise.scala:338)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete0(Promise.scala:285)
# 	at scala.concurrent.impl.Promise$Transformation.run(Promise.scala:504)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl.execute(ExecutionContextImpl.scala:21)
# 	at scala.concurrent.impl.Promise$Transformation.submitWithValue(Promise.scala:429)
# 	at scala.concurrent.impl.Promise$DefaultPromise.submitWithValue(Promise.scala:338)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete0(Promise.scala:285)
# 	at scala.concurrent.impl.Promise$Transformation.run(Promise.scala:504)
# 	at scala.concurrent.ExecutionContext$parasitic$.execute(ExecutionContext.scala:222)
# 	at scala.concurrent.impl.Promise$Transformation.submitWithValue(Promise.scala:429)
# 	at scala.concurrent.impl.Promise$DefaultPromise.submitWithValue(Promise.scala:335)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete0(Promise.scala:285)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:278)
# 	at scala.concurrent.Promise.trySuccess(Promise.scala:99)
# 	at scala.concurrent.Promise.trySuccess$(Promise.scala:99)
# 	at scala.concurrent.impl.Promise$DefaultPromise.trySuccess(Promise.scala:104)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.onSuccess$1(NettyRpcEnv.scala:228)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$askAbortable$5(NettyRpcEnv.scala:242)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$askAbortable$5$adapted(NettyRpcEnv.scala:241)
# 	at scala.concurrent.impl.Promise$Transformation.run(Promise.scala:484)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl.execute(ExecutionContextImpl.scala:21)
# 	at scala.concurrent.impl.Promise$Transformation.submitWithValue(Promise.scala:429)
# 	at scala.concurrent.impl.Promise$DefaultPromise.submitWithValue(Promise.scala:338)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete0(Promise.scala:285)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:278)
# 	at scala.concurrent.Promise.complete(Promise.scala:57)
# 	at scala.concurrent.Promise.complete$(Promise.scala:56)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:104)
# 	at scala.concurrent.Promise.success(Promise.scala:91)
# 	at scala.concurrent.Promise.success$(Promise.scala:91)
# 	at scala.concurrent.impl.Promise$DefaultPromise.success(Promise.scala:104)
# 	at org.apache.spark.rpc.netty.LocalNettyRpcCallContext.send(NettyRpcCallContext.scala:50)
# 	at org.apache.spark.rpc.netty.NettyRpcCallContext.reply(NettyRpcCallContext.scala:32)
# 	at org.apache.spark.rpc.netty.RpcEndpointVerifier$$anonfun$receiveAndReply$1.applyOrElse(RpcEndpointVerifier.scala:31)
# 	... 8 more
# 25/09/09 08:09:37 ERROR Executor: Exit as unable to send heartbeats to driver more than 60 times

# %%
bike_join.show()
# Out:
# +-----------+----------+--------+-----+-------------+------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+-----------------+-----------------+------------------+------------------+
# |device_name|      date|time_gap|count|average_speed|active|             road_nl|             road_fr|             road_en|      description_nl|      description_fr|      description_en|         lane_schema|        basic_schema|     detailed_schema|           picture_1|           picture_2|       lon_wgs_84|       lat_wgs_84|            x_lb72|            y_lb72|
# +-----------+----------+--------+-----+-------------+------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+-----------------+-----------------+------------------+------------------+
# |      CEK31|2020-11-23|      93|    0|           -1|  true|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|4.393037995899081|50.83818200253104|151710.66377625745|169752.30930852424|
# |      CEK31|2020-11-23|      94|    0|           -1|  true|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|4.393037995899081|50.83818200253104|151710.66377625745|169752.30930852424|
# |      CEK31|2020-11-23|      95|    0|           -1|  true|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|4.393037995899081|50.83818200253104|151710.66377625745|169752.30930852424|
# |      CEK31|2020-11-23|      96|    0|           -1|  true|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|4.393037995899081|50.83818200253104|151710.66377625745|169752.30930852424|
# |      CEK31|2020-11-24|       1|    0|           -1|  true|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|4.393037995899081|50.83818200253104|151710.66377625745|169752.30930852424|
# |      CEK31|2020-11-24|       2|    0|           -1|  true|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|4.393037995899081|50.83818200253104|151710.66377625745|169752.30930852424|
# |      CEK31|2020-11-24|       3|    0|           -1|  true|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|4.393037995899081|50.83818200253104|151710.66377625745|169752.30930852424|
# |      CEK31|2020-11-24|       4|    0|           -1|  true|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|4.393037995899081|50.83818200253104|151710.66377625745|169752.30930852424|
# |      CEK31|2020-11-24|       5|    0|           -1|  true|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|4.393037995899081|50.83818200253104|151710.66377625745|169752.30930852424|
# |      CEK31|2020-11-24|       6|    0|           -1|  true|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|4.393037995899081|50.83818200253104|151710.66377625745|169752.30930852424|
# |      CEK31|2020-11-24|       7|    0|           -1|  true|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|4.393037995899081|50.83818200253104|151710.66377625745|169752.30930852424|
# |      CEK31|2020-11-24|       8|    0|           -1|  true|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|4.393037995899081|50.83818200253104|151710.66377625745|169752.30930852424|
# |      CEK31|2020-11-24|       9|    0|           -1|  true|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|4.393037995899081|50.83818200253104|151710.66377625745|169752.30930852424|
# |      CEK31|2020-11-24|      10|    0|           -1|  true|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|4.393037995899081|50.83818200253104|151710.66377625745|169752.30930852424|
# |      CEK31|2020-11-24|      11|    0|           -1|  true|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|4.393037995899081|50.83818200253104|151710.66377625745|169752.30930852424|
# |      CEK31|2020-11-24|      12|    0|           -1|  true|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|4.393037995899081|50.83818200253104|151710.66377625745|169752.30930852424|
# |      CEK31|2020-11-24|      13|    0|           -1|  true|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|4.393037995899081|50.83818200253104|151710.66377625745|169752.30930852424|
# |      CEK31|2020-11-24|      14|    0|           -1|  true|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|4.393037995899081|50.83818200253104|151710.66377625745|169752.30930852424|
# |      CEK31|2020-11-24|      15|    0|           -1|  true|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|4.393037995899081|50.83818200253104|151710.66377625745|169752.30930852424|
# |      CEK31|2020-11-24|      16|    0|           -1|  true|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|4.393037995899081|50.83818200253104|151710.66377625745|169752.30930852424|
# +-----------+----------+--------+-----+-------------+------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+-----------------+-----------------+------------------+------------------+
# only showing top 20 rows

# %%
# bbc
# save the data as csv 
bike_join.write.mode("overwrite").csv("../data/processed/bike_counts.csv")

# %%
# save the data as parquet

bike_join.write.mode("overwrite").parquet("../data/processed/bike_counts.parquet")
# Out:
# 25/09/08 15:47:00 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers

# %%
# create a datetime comumn

from pyspark.sql.functions import to_timestamp, col, expr, add_months, concat,lpad

df_with_time = bike_join.withColumn(
    "time",
    concat(
        lpad(expr("cast(((time_gap - 1) * 15) / 60 as int)"), 2, '0'),
        expr("':'"),
        lpad(expr("cast(((time_gap - 1) * 15) % 60 as int)"), 2, '0'),
        expr("':00'")
    )
)

# %%
df_with_time.show()
# Out:
# +-----------+----------+--------+-----+-------------+------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+-----------------+-----------------+------------------+------------------+--------+
# |device_name|      date|time_gap|count|average_speed|active|             road_nl|             road_fr|             road_en|      description_nl|      description_fr|      description_en|         lane_schema|        basic_schema|     detailed_schema|           picture_1|           picture_2|       lon_wgs_84|       lat_wgs_84|            x_lb72|            y_lb72|    time|
# +-----------+----------+--------+-----+-------------+------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+-----------------+-----------------+------------------+------------------+--------+
# |      CEK31|2020-11-23|      93|    0|           -1|  true|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|4.393037995899081|50.83818200253104|151710.66377625745|169752.30930852424|23:00:00|
# |      CEK31|2020-11-23|      94|    0|           -1|  true|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|4.393037995899081|50.83818200253104|151710.66377625745|169752.30930852424|23:15:00|
# |      CEK31|2020-11-23|      95|    0|           -1|  true|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|4.393037995899081|50.83818200253104|151710.66377625745|169752.30930852424|23:30:00|
# |      CEK31|2020-11-23|      96|    0|           -1|  true|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|4.393037995899081|50.83818200253104|151710.66377625745|169752.30930852424|23:45:00|
# |      CEK31|2020-11-24|       1|    0|           -1|  true|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|4.393037995899081|50.83818200253104|151710.66377625745|169752.30930852424|00:00:00|
# |      CEK31|2020-11-24|       2|    0|           -1|  true|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|4.393037995899081|50.83818200253104|151710.66377625745|169752.30930852424|00:15:00|
# |      CEK31|2020-11-24|       3|    0|           -1|  true|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|4.393037995899081|50.83818200253104|151710.66377625745|169752.30930852424|00:30:00|
# |      CEK31|2020-11-24|       4|    0|           -1|  true|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|4.393037995899081|50.83818200253104|151710.66377625745|169752.30930852424|00:45:00|
# |      CEK31|2020-11-24|       5|    0|           -1|  true|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|4.393037995899081|50.83818200253104|151710.66377625745|169752.30930852424|01:00:00|
# |      CEK31|2020-11-24|       6|    0|           -1|  true|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|4.393037995899081|50.83818200253104|151710.66377625745|169752.30930852424|01:15:00|
# |      CEK31|2020-11-24|       7|    0|           -1|  true|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|4.393037995899081|50.83818200253104|151710.66377625745|169752.30930852424|01:30:00|
# |      CEK31|2020-11-24|       8|    0|           -1|  true|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|4.393037995899081|50.83818200253104|151710.66377625745|169752.30930852424|01:45:00|
# |      CEK31|2020-11-24|       9|    0|           -1|  true|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|4.393037995899081|50.83818200253104|151710.66377625745|169752.30930852424|02:00:00|
# |      CEK31|2020-11-24|      10|    0|           -1|  true|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|4.393037995899081|50.83818200253104|151710.66377625745|169752.30930852424|02:15:00|
# |      CEK31|2020-11-24|      11|    0|           -1|  true|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|4.393037995899081|50.83818200253104|151710.66377625745|169752.30930852424|02:30:00|
# |      CEK31|2020-11-24|      12|    0|           -1|  true|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|4.393037995899081|50.83818200253104|151710.66377625745|169752.30930852424|02:45:00|
# |      CEK31|2020-11-24|      13|    0|           -1|  true|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|4.393037995899081|50.83818200253104|151710.66377625745|169752.30930852424|03:00:00|
# |      CEK31|2020-11-24|      14|    0|           -1|  true|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|4.393037995899081|50.83818200253104|151710.66377625745|169752.30930852424|03:15:00|
# |      CEK31|2020-11-24|      15|    0|           -1|  true|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|4.393037995899081|50.83818200253104|151710.66377625745|169752.30930852424|03:30:00|
# |      CEK31|2020-11-24|      16|    0|           -1|  true|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|4.393037995899081|50.83818200253104|151710.66377625745|169752.30930852424|03:45:00|
# +-----------+----------+--------+-----+-------------+------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+-----------------+-----------------+------------------+------------------+--------+
# only showing top 20 rows

# %%
# combine date a
df_with_time.select("time").show(5)
# Out:
# +--------+
# |    time|
# +--------+
# |23:00:00|
# |23:15:00|
# |23:30:00|
# |23:45:00|
# |00:00:00|
# +--------+
# only showing top 5 rows

# %%
from pyspark.sql.functions import concat_ws

df_with_datetime = df_with_time.withColumn(
    "datetime",
    to_timestamp(concat_ws(" ",col("date").cast("string"),col("time")))
).drop("time")

# %%
df_with_datetime.select("datetime").show()
# Out:
# +-------------------+
# |           datetime|
# +-------------------+
# |2020-11-23 23:00:00|
# |2020-11-23 23:15:00|
# |2020-11-23 23:30:00|
# |2020-11-23 23:45:00|
# |2020-11-24 00:00:00|
# |2020-11-24 00:15:00|
# |2020-11-24 00:30:00|
# |2020-11-24 00:45:00|
# |2020-11-24 01:00:00|
# |2020-11-24 01:15:00|
# |2020-11-24 01:30:00|
# |2020-11-24 01:45:00|
# |2020-11-24 02:00:00|
# |2020-11-24 02:15:00|
# |2020-11-24 02:30:00|
# |2020-11-24 02:45:00|
# |2020-11-24 03:00:00|
# |2020-11-24 03:15:00|
# |2020-11-24 03:30:00|
# |2020-11-24 03:45:00|
# +-------------------+
# only showing top 20 rows

# %%
# use plotly to visualise
# total number of bike_counts aggregated per year
from pyspark.sql.functions import year, sum

# get year

df_with_year = df_with_datetime.withColumn("year",year("datetime"))

# %%
df_with_year.show()
# Out:
# +-----------+----------+--------+-----+-------------+------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+-----------------+-----------------+------------------+------------------+-------------------+----+
# |device_name|      date|time_gap|count|average_speed|active|             road_nl|             road_fr|             road_en|      description_nl|      description_fr|      description_en|         lane_schema|        basic_schema|     detailed_schema|           picture_1|           picture_2|       lon_wgs_84|       lat_wgs_84|            x_lb72|            y_lb72|           datetime|year|
# +-----------+----------+--------+-----+-------------+------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+-----------------+-----------------+------------------+------------------+-------------------+----+
# |      CEK31|2020-11-23|      93|    0|           -1|  true|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|4.393037995899081|50.83818200253104|151710.66377625745|169752.30930852424|2020-11-23 23:00:00|2020|
# |      CEK31|2020-11-23|      94|    0|           -1|  true|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|4.393037995899081|50.83818200253104|151710.66377625745|169752.30930852424|2020-11-23 23:15:00|2020|
# |      CEK31|2020-11-23|      95|    0|           -1|  true|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|4.393037995899081|50.83818200253104|151710.66377625745|169752.30930852424|2020-11-23 23:30:00|2020|
# |      CEK31|2020-11-23|      96|    0|           -1|  true|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|4.393037995899081|50.83818200253104|151710.66377625745|169752.30930852424|2020-11-23 23:45:00|2020|
# |      CEK31|2020-11-24|       1|    0|           -1|  true|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|4.393037995899081|50.83818200253104|151710.66377625745|169752.30930852424|2020-11-24 00:00:00|2020|
# |      CEK31|2020-11-24|       2|    0|           -1|  true|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|4.393037995899081|50.83818200253104|151710.66377625745|169752.30930852424|2020-11-24 00:15:00|2020|
# |      CEK31|2020-11-24|       3|    0|           -1|  true|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|4.393037995899081|50.83818200253104|151710.66377625745|169752.30930852424|2020-11-24 00:30:00|2020|
# |      CEK31|2020-11-24|       4|    0|           -1|  true|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|4.393037995899081|50.83818200253104|151710.66377625745|169752.30930852424|2020-11-24 00:45:00|2020|
# |      CEK31|2020-11-24|       5|    0|           -1|  true|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|4.393037995899081|50.83818200253104|151710.66377625745|169752.30930852424|2020-11-24 01:00:00|2020|
# |      CEK31|2020-11-24|       6|    0|           -1|  true|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|4.393037995899081|50.83818200253104|151710.66377625745|169752.30930852424|2020-11-24 01:15:00|2020|
# |      CEK31|2020-11-24|       7|    0|           -1|  true|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|4.393037995899081|50.83818200253104|151710.66377625745|169752.30930852424|2020-11-24 01:30:00|2020|
# |      CEK31|2020-11-24|       8|    0|           -1|  true|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|4.393037995899081|50.83818200253104|151710.66377625745|169752.30930852424|2020-11-24 01:45:00|2020|
# |      CEK31|2020-11-24|       9|    0|           -1|  true|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|4.393037995899081|50.83818200253104|151710.66377625745|169752.30930852424|2020-11-24 02:00:00|2020|
# |      CEK31|2020-11-24|      10|    0|           -1|  true|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|4.393037995899081|50.83818200253104|151710.66377625745|169752.30930852424|2020-11-24 02:15:00|2020|
# |      CEK31|2020-11-24|      11|    0|           -1|  true|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|4.393037995899081|50.83818200253104|151710.66377625745|169752.30930852424|2020-11-24 02:30:00|2020|
# |      CEK31|2020-11-24|      12|    0|           -1|  true|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|4.393037995899081|50.83818200253104|151710.66377625745|169752.30930852424|2020-11-24 02:45:00|2020|
# |      CEK31|2020-11-24|      13|    0|           -1|  true|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|4.393037995899081|50.83818200253104|151710.66377625745|169752.30930852424|2020-11-24 03:00:00|2020|
# |      CEK31|2020-11-24|      14|    0|           -1|  true|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|4.393037995899081|50.83818200253104|151710.66377625745|169752.30930852424|2020-11-24 03:15:00|2020|
# |      CEK31|2020-11-24|      15|    0|           -1|  true|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|4.393037995899081|50.83818200253104|151710.66377625745|169752.30930852424|2020-11-24 03:30:00|2020|
# |      CEK31|2020-11-24|      16|    0|           -1|  true|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|NerviÃ«rslaan 135...|Avenue des Nervie...|Avenue des Nervie...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|https://data.mobi...|4.393037995899081|50.83818200253104|151710.66377625745|169752.30930852424|2020-11-24 03:45:00|2020|
# +-----------+----------+--------+-----+-------------+------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+-----------------+-----------------+------------------+------------------+-------------------+----+
# only showing top 20 rows

# %%
# group by station and year, aggregate by sum of counts

df_yearly = df_with_year.groupBy("device_name","year").agg(sum("count").alias("total_count")).orderBy("device_name","year")

# %%
df_yearly.show()
# Out:
# [Stage 27:=======>                                                  (1 + 7) / 8]
# +-----------+----+-----------+
# |device_name|year|total_count|
# +-----------+----+-----------+
# |      CAT17|2020|      46033|
# |      CAT17|2021|     423492|
# |      CAT17|2022|     533284|
# |      CAT17|2023|     545711|
# |      CAT17|2024|     569622|
# |    CB02411|2019|     436553|
# |    CB02411|2020|     664437|
# |    CB02411|2021|     604896|
# |    CB02411|2022|     824891|
# |    CB02411|2023|    1052527|
# |    CB02411|2024|    1105636|
# |     CB1101|2022|      14195|
# |     CB1101|2023|    1456137|
# |     CB1101|2024|    1427037|
# |     CB1142|2019|     351174|
# |     CB1142|2020|     585926|
# |     CB1142|2021|     660553|
# |     CB1142|2022|    1023809|
# |     CB1142|2023|    1049197|
# |     CB1142|2024|     700479|
# +-----------+----+-----------+
# only showing top 20 rows

# %%
# to visualise on plotly, need to convert the spark dataframe to pandas dataframe
pdf = df_yearly.toPandas()

# pivot for wide format: years as rows, stations as columns

pivot_pdf =pdf.pivot(index='year',columns='device_name',values="total_count")

import plotly.express as px

fig = px.line(
    pivot_pdf,
    x=pivot_pdf.index,
    y=pivot_pdf.columns,
    labels={'x': 'Year', 'value':'Total Bike count', 'variable':'Station'},
    title='Total Bike Counts Per Year Per Station'
)

fig.show()

# %%
import nbformat

# %%
# filtering the pandas dataframe for year 2024

df_yearly_2024 = pdf[pdf['year']==2024]
df_yearly_2024.head()
# Out:
#    device_name  year  total_count
# 4        CAT17  2024       569622
# 10     CB02411  2024      1105636
# 13      CB1101  2024      1427037
# 19      CB1142  2024       700479
# 25      CB1143  2024       930700

# %%
# aggregate but maintain the latitude and longitude


# group by station and year, aggregate by sum of counts

df_2024 = df_with_year.filter(df_with_year.year == 2024).groupBy("device_name","lat_wgs_84","lon_wgs_84").agg(sum("count").alias("total_count_2024")).orderBy("device_name")

# %%
df_2024.show()
# Out:
# [Stage 40:=======>                                                  (1 + 7) / 8]
# +-----------+------------------+------------------+----------------+
# |device_name|        lat_wgs_84|        lon_wgs_84|total_count_2024|
# +-----------+------------------+------------------+----------------+
# |      CAT17|50.820621002525904| 4.301991995919691|          569622|
# |    CB02411| 50.88185000251615| 4.373960995908418|         1105636|
# |     CB1101| 50.84534100252618|  4.36858299590588|         1427037|
# |     CB1142|50.843570002527876| 4.378737995903186|          700479|
# |     CB1143| 50.84337000252792| 4.378813995903146|          930700|
# |     CB1599| 50.81240800253699| 4.379253995899753|          325219|
# |     CB1699| 50.81228000253699| 4.378799995899851|          297998|
# |     CB2105| 50.84048000252439| 4.340009995912418|          611051|
# |     CEE016| 50.82137600253522| 4.386718995898861|          512085|
# |     CEK049| 50.82448000253513| 4.393892995897416|          713978|
# |      CEK18| 50.83920000253155| 4.400258995897405|          435371|
# |      CEK31| 50.83818200253104| 4.393037995899081|          701753|
# |     CEV011| 50.86692100252375| 4.402934995899683|          177772|
# |     CJE181| 50.88029700251005| 4.315713995922622|          104181|
# |      CJM90|  50.8536300025207| 4.341239995913506|         1699534|
# |     CLW239| 50.83799800253579|4.4348299958887285|          210320|
# |     COM205| 50.82029000254048| 4.430120995888016|          420932|
# |     CVT387|50.805366002531436| 4.311588995915708|          174979|
# +-----------+------------------+------------------+----------------+

# %%
# plot on a map
# convert to pandas dataframe
pdf_2024 = df_2024.toPandas()
import plotly.express as px

fig = px.scatter(
    pdf_2024,
    x='lon_wgs_84',
    y='lat_wgs_84',
    size='total_count_2024',
    color = 'total_count_2024',
    hover_name='device_name',
    title='Bike Counts Per Station',
    labels={'lon_wgs_84':'Longitude','lat_wgs_84':'Latitude','total_count_2024':'Total Count'}
)

fig.show()

# %%
# map
fig = px.scatter_mapbox(
    pdf_2024,
    lat='lat_wgs_84',
    lon='lon_wgs_84',
    size='total_count_2024',
    color = 'total_count_2024',
    hover_name='device_name',
    zoom=11,
    mapbox_style='carto-positron',
    title='Bike Counts Per Station'
)

fig.show()
# Out:
# /var/folders/x4/8zknt51125zgpkhmsynyw7k00000gn/T/ipykernel_26050/1381664645.py:2: DeprecationWarning:
#
# *scatter_mapbox* is deprecated! Use *scatter_map* instead. Learn more at: https://plotly.com/python/mapbox-to-maplibre/

# %%
# map
fig = px.scatter_map(
    pdf_2024,
    lat='lat_wgs_84',
    lon='lon_wgs_84',
    size='total_count_2024',
    color = 'total_count_2024',
    hover_name='device_name',
    zoom=11,
    title='Bike Counts Per Station'
)

fig.show()
